# %%
# !pip install pandas

# %%
import os
import shutil
import pandas as pd
import numpy as np

# %%
cat = pd.read_csv("train.csv")
cat.head()

path_img = "/Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/"
path_save = "/Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/"

for i, row in cat.iterrows() :
    
    name = path_img+row.image
    cate = path_save + str(row.category) + "/" + row.image
    
    print (name)
    print (cate)
    
    shutil.copy(name,cate)
# Out:
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/2823080.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/1/2823080.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/2870024.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/1/2870024.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/2662125.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/2/2662125.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/2900420.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/3/2900420.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/images/2804883.jpg
# /Users/gim-yeong-u/Documents/GitHub/YOLO_ship/data_crawling/kaggle_open data/sort/2/2804883.jpg
# ...
